# %% [markdown]
# #                                     Assignment No 4

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_data.csv")
data.loc[[16, 38, 67, 97, 117]]
# Out:
#     show_id     type                                              title  \
# 16      s17  TV Show                                             Feb-09
# 38      s39  TV Show                                แผนร้ายนายเจ้าเล่ห์
# 67      s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 97      s98    Movie                                        3 Deewarein
# 117    s118    Movie                                     5 Cowok Jagoan
#
#             director                                               cast  \
# 16               NaN  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# 38               NaN  Chutavuth Pattarakampol, Sheranut Yusananda, N...
# 67               NaN                        Oprah Winfrey, Ava DuVernay
# 97   Nagesh Kukunoor  Naseeruddin Shah, Jackie Shroff, Juhi Chawla, ...
# 117     Anggy Umbara  Ario Bayu, Arifin Putra, Dwi Sasono, Muhadkly ...
#
#     country         date_added  release_year  duration  \
# ...

# %% [markdown]
# ## Q1: In the netflix dataset replace all null values present in country column with united states.

# %%
data["country"].fillna("United states", inplace=True)
data.loc[[16, 38, 67, 97, 117]]
# Out:
#     show_id     type                                              title  \
# 16      s17  TV Show                                             Feb-09
# 38      s39  TV Show                                แผนร้ายนายเจ้าเล่ห์
# 67      s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 97      s98    Movie                                        3 Deewarein
# 117    s118    Movie                                     5 Cowok Jagoan
#
#             director                                               cast  \
# 16               NaN  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# 38               NaN  Chutavuth Pattarakampol, Sheranut Yusananda, N...
# 67               NaN                        Oprah Winfrey, Ava DuVernay
# 97   Nagesh Kukunoor  Naseeruddin Shah, Jackie Shroff, Juhi Chawla, ...
# 117     Anggy Umbara  Ario Bayu, Arifin Putra, Dwi Sasono, Muhadkly ...
#
#            country         date_added  release_year  duration  \
# ...

# %% [markdown]
# ## Q2: Show 10 countries with most tv-shows and movies

# %%
d = data.groupby("country").count()
d.head(10)
# Out:
#             show_id  type  title  director  cast  date_added  release_year  \
# country
# Argentina        68    68     68        51    62          68            68
# Australia       108   108    108        57    95         107           108
# Austria           8     8      8         7     6           8             8
# Bangladesh        2     2      2         2     2           2             2
# Belarus           1     1      1         0     1           1             1
# Belgium          14    14     14         7    13          14            14
# Brazil           79    79     79        55    69          79            79
# Bulgaria          5     5      5         5     5           5             5
# Cambodia          2     2      2         2     2           2             2
# Canada          259   259    259       173   234         259           259
#
#             duration  description  genre
# country
# Argentina         68           68     68
# ...

# %%
type_movie = data[data['type'] == 'Movie']
type_movie.head()
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
# 6       June 1, 2020          2019        95
#
# ...

# %% [markdown]
# ## Q3: Count of movies released in year respective years. example
# 2017   9
#
# 2018   7
# this shows 9 movies released in 2017 and 7 in 2018. Like for every year.
#
# ## The answer is
# ### 2017 year movies count 744

# %%
type_movie[type_movie['release_year'] == 2017].count()
# Out:
# show_id         744
# type            744
# title           744
# director        725
# cast            654
# country         744
# date_added      744
# release_year    744
# duration        744
# description     744
# genre           744
# dtype: int64

# %% [markdown]
# ### 2018 year movies count 734

# %%
type_movie[type_movie['release_year'] == 2018].count()
# Out:
# show_id         734
# type            734
# title           734
# director        704
# cast            666
# country         734
# date_added      734
# release_year    734
# duration        734
# description     734
# genre           734
# dtype: int64

# %% [markdown]
# ## Q4: Similarly, count of tv-shows released in there respective years.

# %%
type_tv_shows = data[data['type'] == 'TV Show']
type_tv_shows.head()
# Out:
#    show_id     type   title              director  \
# 0       s1  TV Show      3%                   NaN
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09                   NaN
#
#                                                  cast        country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...         Poland
# 12                                                NaN         Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...  United states
#
#            date_added  release_year  duration  \
# 0     August 14, 2020          2020         4
# 5        July 1, 2017          2016         1
# 11  November 30, 2018          2018         1
# 12       May 17, 2019          2019         1
# ...

# %% [markdown]
# ### 2017 year TV Shows count 268

# %%
type_tv_shows[type_tv_shows['release_year'] == 2017].count()
# Out:
# show_id         268
# type            268
# title           268
# director         25
# cast            239
# country         268
# date_added      268
# release_year    268
# duration        268
# description     268
# genre           268
# dtype: int64

# %% [markdown]
# ### 2018 year TV Shows count 387

# %%
type_tv_shows[type_tv_shows['release_year'] == 2018].count()
# Out:
# show_id         387
# type            387
# title           387
# director         24
# cast            334
# country         387
# date_added      386
# release_year    387
# duration        387
# description     387
# genre           387
# dtype: int64
